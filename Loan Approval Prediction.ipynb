# %% [markdown]
# <div style="border-radius:10px; padding: 30px; background-color: #26bfbf; font-size:90%; text-align:left">
# <p style="font-family:Georgia; font-size:400%;font-weight:bold;text-align:center;color:navy;"> 💰 Loan Approval Prediction 🏦 </p>
#
#
# <p style="font-family:newtimeroman; font-size:200%;font-weight:bold;text-align:center;color:navy;">coder : Goyupov Dilmurod👨‍💻</p> </div>

# %% [markdown]
# <center>
#
# # ![0_GItNE4aJ4Z7t3Gp0(1).png](attachment:50ec54ed-e7d9-4fff-8b6a-d82cd906f65c.png)

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #26bfbf; font-size:120%; text-align:left">
# <h3 align="left"><font color="navy"> <center>Bizda Loan Approval Prediction(Kreditni tasdiqlash bashorati) nomli dataset bor, Biz bu datasetni o'rganib chiqamiz va kredit berish bo'yicha bashorati amalga oshiramiz 💼</font></h3>
# <center> <a href="https://www.kaggle.com/competitions/playground-series-s4e10">Datasetni quyidagi havola orqali yuklab olishingiz mumkin.</a>
#
# </div>

# %% [markdown]
# <div style="border-radius:50px; padding: 1px; background-color: #26bfbf; font-size:130%; text-align:left">
# <h3 align="left"><font color="navy"> <center><center> 1 - qadam. Kerakli kutubxonlarni chaqirib olamiz. </font></h3>
# </div>

# %%
import pandas as pd  # Dataset bilan ishlash uchun kerak
import matplotlib.pyplot as plt # grafiklar bilan ishlsh uchun kerak
import matplotlib.ticker as mticker # grafiklar bilan ishlsh uchun kerak
import seaborn as sns # grafiklar bilan ishlash uchun kerak
from sklearn.preprocessing import LabelEncoder # Encode uchun kerak

# %% [markdown]
# <div style="border-radius:50px; padding: 1px; background-color: #26bfbf; font-size:130%; text-align:left">
# <h3 align="left"><font color="navy"> <center><center>  2-qadam. Datasetni o'qib olamiz.</font></h3>
# </div>

# %%
data = pd.read_csv("Datasets/kredit/train.csv")
data
# Out:
#           id  person_age  person_income person_home_ownership  \
# 0          0          37          35000                  RENT
# 1          1          22          56000                   OWN
# 2          2          29          28800                   OWN
# 3          3          30          70000                  RENT
# 4          4          22          60000                  RENT
# ...      ...         ...            ...                   ...
# 58640  58640          34         120000              MORTGAGE
# 58641  58641          28          28800                  RENT
# 58642  58642          23          44000                  RENT
# 58643  58643          22          30000                  RENT
# 58644  58644          31          75000              MORTGAGE
#
#        person_emp_length loan_intent loan_grade  loan_amnt  loan_int_rate  \
# 0                    0.0   EDUCATION          B       6000          11.49
# ...

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; font-size:115%; text-align:left">
#
# <h3 align="left"><font color=cyan>Dataset haqida ma'lumot:</font></h3>
#
# | __Index__ | __Ustun__                  | __Description__                                                                 |
# |:----------|:------------------------------|:--------------------------------------------------------------------------------|
# | 1         | __id__                        | _bu datamizning id raqami._                                           |
# | 2         | __person_age__               | _kredit olmoqchi bo'lgan odamning yoshi._                                                         |
# | 3         | __person_income__            | _kredit olmoqchi bo'lgan insonning daromadi._                                              |
# | 4         | __person_home_ownership__    | kredit olmoqchi bo'lgan odamning uyi haqidagi ma'lumot. Ya'ni unda o'zining uyi bormi yoki u ijarada turadimi va hakazo.                                     |
# | 5         | __person_emp_length__        | _bu ish staji._                                               |
# | 6         | __loan_intent__              | kreditning maqsadi.               |
# | 7         | __loan_grade__               | kredit bo'yicha reytingi.                                   |
# | 8         | __loan_amnt__                | _kredit miqdori._                                                           |
# | 9         | __loan_int_rate__            | _kredit bo'yicha foiz miqdori._                                                    |
# | 10        | __loan_percent_income__      | _bu kredit oluvchining yillik daromadining necha foizini kreditni to'lash uchun sarflashni rejalashtirayotganini ko'rsatadi._                               |
# | 11        | __cb_person_default_on_file__| _kredit bo'yicha default. Ya'ni oldingi kreditlari bo'yicha o'z vazifalarini bajargan yoki bajarmagan(to'lamagan)._                     |
# | 12        | __cb_person_cred_hist_length__| _bu uning qancha vaqtdan beri kreditlar olayotganini bildiradi._                                    |
# | 13        | __loan_status__              | _kreditning statusi._                      |

# %%
data.info()
# bizning datasetimiz to'liq ekan
# 4 ta object ustuni bor ekan
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58645 entries, 0 to 58644
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          58645 non-null  int64
#  1   person_age                  58645 non-null  int64
#  2   person_income               58645 non-null  int64
#  3   person_home_ownership       58645 non-null  object
#  4   person_emp_length           58645 non-null  float64
#  5   loan_intent                 58645 non-null  object
#  6   loan_grade                  58645 non-null  object
#  7   loan_amnt                   58645 non-null  int64
#  8   loan_int_rate               58645 non-null  float64
#  9   loan_percent_income         58645 non-null  float64
#  10  cb_person_default_on_file   58645 non-null  object
#  11  cb_person_cred_hist_length  58645 non-null  int64
#  12  loan_status                 58645 non-null  int64
# ...

# %%
data.describe()
# Out:
#                  id    person_age  person_income  person_emp_length  \
# count  58645.000000  58645.000000   5.864500e+04       58645.000000
# mean   29322.000000     27.550857   6.404617e+04           4.701015
# std    16929.497605      6.033216   3.793111e+04           3.959784
# min        0.000000     20.000000   4.200000e+03           0.000000
# 25%    14661.000000     23.000000   4.200000e+04           2.000000
# 50%    29322.000000     26.000000   5.800000e+04           4.000000
# 75%    43983.000000     30.000000   7.560000e+04           7.000000
# max    58644.000000    123.000000   1.900000e+06         123.000000
#
#           loan_amnt  loan_int_rate  loan_percent_income  \
# count  58645.000000   58645.000000         58645.000000
# mean    9217.556518      10.677874             0.159238
# std     5563.807384       3.034697             0.091692
# min      500.000000       5.420000             0.000000
# 25%     5000.000000       7.880000             0.090000
# ...

# %%
data.describe(include=object)
# Out:
#        person_home_ownership loan_intent loan_grade cb_person_default_on_file
# count                  58645       58645      58645                     58645
# unique                     4           6          7                         2
# top                     RENT   EDUCATION          A                         N
# freq                   30594       12271      20984                     49943

# %%
data.drop(["id"], axis=1, inplace=True)
# id ustunini o'chirib tashlaymiz

# %%
plt.subplots(figsize=(9,9))
sns.heatmap(data.corr(numeric_only=True),annot=True, fmt='.2f')
# ustunlar orasidagi korelatsiyani ko'rib chiqamiz
# Out:
# <Axes: >

# %%
data.corrwith(data["loan_status"], numeric_only=True).sort_values()
# e'tibor beradigan bo'lsak person_age(yosh) korealsiyasi loan_statusga(Kredit olishga) nisbatan eng past ekan
# Out:
# person_income                -0.169956
# person_emp_length            -0.100428
# cb_person_cred_hist_length   -0.003030
# person_age                   -0.001130
# loan_amnt                     0.144982
# loan_int_rate                 0.338948
# loan_percent_income           0.378280
# loan_status                   1.000000
# dtype: float64

# %%
# Classlarning farqini ko'ramiz
class_counts = data["loan_status"].value_counts()
print(class_counts)
# Asosiy class orasidagi farq juda katta ekan
# buni to'ldiramiz
# Out:
# loan_status
# 0    50295
# 1     8350
# Name: count, dtype: int64

# %%
# raqamli va yozuvli ustunlarni belgilab olamiz
numerical_columns = ['person_income', 'loan_amnt', 'person_emp_length', 'loan_int_rate', 'loan_percent_income', 'person_age', 'cb_person_cred_hist_length']
categorical_columns = ['person_home_ownership', 'loan_intent', 'loan_grade', 'cb_person_default_on_file']

# %%
#Label encoderni hamma yozuvli ustunlarga qo'llaymiz
label_encoders = {}

# hamma object ustnlarni raqamli ko'rinishga o'tkazib olamiz
for col in categorical_columns:
    le = LabelEncoder()
    data[col] = le.fit_transform(data[col])
    label_encoders[col] = le

# %%
data
# Out:
#        person_age  person_income  person_home_ownership  person_emp_length  \
# 0              37          35000                      3                0.0
# 1              22          56000                      2                6.0
# 2              29          28800                      2                8.0
# 3              30          70000                      3               14.0
# 4              22          60000                      3                2.0
# ...           ...            ...                    ...                ...
# 58640          34         120000                      0                5.0
# 58641          28          28800                      3                0.0
# 58642          23          44000                      3                7.0
# 58643          22          30000                      3                2.0
# 58644          31          75000                      0                2.0
#
# ...

# %% [markdown]
# <div style="border-radius:50px; padding: 1px; background-color: #26bfbf; font-size:130%; text-align:left">
# <h3 align="left"><font color="navy"> <center><center>  3-qadam. Data augmentatsiya.</font></h3>
# </div>

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #26bfbf; font-size:110%; text-align:left">
# <h3 align="left"><font color="navy"> <center> Datamizni to'ldirish uchun biz imblearn kutubxonasidagi SMOTENC metdodidan foydalanamiz. Bu metod SMOTE(Synthetic Minority Oversampling Technique) - oilasiga mansub bo'lib kam classlarni to'ldirish uchun xizmat qiladi. U bir xil sinfning tasodifiy datalari orasidagi chiziqli interpolyatsiyadan foydalangan holda ishlaydi. Ya'nada soddaroq aytadigan bo'lsak u knn(k ta eng yaqin qo'shnilar) orqali ishlaydi. Ya'ni uning qo'shnilari orqali yangi datalar hosil qilinadi.</font></h3>
#
#
# </div>

# %%
from imblearn.over_sampling import SMOTENC

# %%
# 1-bo'lib. Datani X va y ga ajratib olamiz
X = data.drop('loan_status', axis=1)  
y = data['loan_status']

# %%
# Object ustunlarni indexini olamiz
categorical_features_indices = [X.columns.get_loc(col) for col in categorical_columns]

# %%
# SMOTENC-dan obyektini yaratib olamiz
# biz object ustunlari Numeric qilgan bo'lsak ham SMOTENC-ga bular haqida ko'ratishimiz kerak bo'ladi.
smote_nc = SMOTENC(categorical_features=categorical_features_indices, random_state=42, k_neighbors=5)

# %%
# SMOTENC ishlatamiz
X_resampled, y_resampled = smote_nc.fit_resample(X, y)

# %%
# Kerali ustunlarni datamiz oldin qanday formatda yaxlitlangan bo'lsa xuddi shunday yaxlitlashga o'tkazamiz
X_resampled['person_emp_length'] = X_resampled['person_emp_length'].round(0)  # nuqtadan keyin 0 tagacha
X_resampled['loan_int_rate'] = X_resampled['loan_int_rate'].round(2)         # nuqtadan keyin 2 tagacha
X_resampled['loan_percent_income'] = X_resampled['loan_percent_income'].round(2)  # nuqtadan keyin 2 tagacha

# %%
X_resampled
# Out:
#         person_age  person_income  person_home_ownership  person_emp_length  \
# 0               37          35000                      3                0.0
# 1               22          56000                      2                6.0
# 2               29          28800                      2                8.0
# 3               30          70000                      3               14.0
# 4               22          60000                      3                2.0
# ...            ...            ...                    ...                ...
# 100585          23          44000                      3                7.0
# 100586          27          42000                      3                3.0
# 100587          31          33530                      3                3.0
# 100588          31          34000                      3                0.0
# 100589          26          32000                      3                0.0
#
# ...

# %%
# Datamizni yaxshilab o'rganish uchun oldingi holatiga qaytarib olamiz
for col in categorical_columns:
    X_resampled[col] = label_encoders[col].inverse_transform(X_resampled[col])

# %%
X_resampled
# Out:
#         person_age  person_income person_home_ownership  person_emp_length  \
# 0               37          35000                  RENT                0.0
# 1               22          56000                   OWN                6.0
# 2               29          28800                   OWN                8.0
# 3               30          70000                  RENT               14.0
# 4               22          60000                  RENT                2.0
# ...            ...            ...                   ...                ...
# 100585          23          44000                  RENT                7.0
# 100586          27          42000                  RENT                3.0
# 100587          31          33530                  RENT                3.0
# 100588          31          34000                  RENT                0.0
# 100589          26          32000                  RENT                0.0
#
# ...

# %%
# umumiy datasetga yangi yaratgan datasetimizni qo'shamiz
data = pd.concat([pd.DataFrame(X_resampled, columns=X.columns), pd.DataFrame(y_resampled, columns=['loan_status'])], axis=1)

# %%
data
# Out:
#         person_age  person_income person_home_ownership  person_emp_length  \
# 0               37          35000                  RENT                0.0
# 1               22          56000                   OWN                6.0
# 2               29          28800                   OWN                8.0
# 3               30          70000                  RENT               14.0
# 4               22          60000                  RENT                2.0
# ...            ...            ...                   ...                ...
# 100585          23          44000                  RENT                7.0
# 100586          27          42000                  RENT                3.0
# 100587          31          33530                  RENT                3.0
# 100588          31          34000                  RENT                0.0
# 100589          26          32000                  RENT                0.0
#
# ...

# %%
# Classlar orasidagi balansi ko'ramiz
print(data['loan_status'].value_counts())
# balans to'gri
# Out:
# loan_status
# 0    50295
# 1    50295
# Name: count, dtype: int64

# %%
# ya'na bir bor null qiymatlarni tekshiramimz
print(data.isnull().sum())
# Out:
# person_age                    0
# person_income                 0
# person_home_ownership         0
# person_emp_length             0
# loan_intent                   0
# loan_grade                    0
# loan_amnt                     0
# loan_int_rate                 0
# loan_percent_income           0
# cb_person_default_on_file     0
# cb_person_cred_hist_length    0
# loan_status                   0
# dtype: int64

# %% [markdown]
# <div style="border-radius:50px; padding: 1px; background-color: #26bfbf; font-size:130%; text-align:left">
# <h3 align="left"><font color="navy"> <center><center> 4-qadam. Visualizing va Preprocessing. </font></h3>
# </div>

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=data, x="person_home_ownership", y="person_income", palette="pastel")
plt.title("Daromadlarni uy-joy mulki bo'yicha taqsimlanishi", fontsize=14)
plt.xlabel("Uy-joy mulkining turi", fontsize=12)
plt.ylabel("Daromad ", fontsize=12)

plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'{int(x):,}'))

plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()
# Out:
# C:\Users\djdle\AppData\Local\Temp\ipykernel_4852\3334695246.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x="person_home_ownership", y="person_income", palette="pastel")

# %%
# Tepadagi grafikka e'tibor beradigan bo'lsak outlier datalar ko'p ekan lekin ularni hammasini ham o'chirib tashlash yaxshi emas
# Keling 1 000 000 dan yuqori daromadliklarni ko'rib chiqamiz
data[data["person_income"]>1000000]
# demak bizda  daromadi 1 000 000 dan yuqori 5 ta data bor ekan
# va ularning hammasini kredit statusi 0 ya'ni kredit ololmagan
# 3-dataga qarasak 22 yoshlik arizachining daromadi 1 900 000 ekan bu xato data bo'lishi mumkin
# 1000000 dan baland datalarni o'chirib tashlaymiz
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 2093           32        1200000                  RENT                2.0
# 12404          25        1839784                  RENT                0.0
# 17387          22        1900000              MORTGAGE                6.0
# 19060          32        1200000              MORTGAGE               16.0
# 37591          29        1824000              MORTGAGE                8.0
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate  \
# 2093            PERSONAL          A      10000           7.51
# 12404            VENTURE          A       8000           8.00
# 17387          EDUCATION          D       1500          15.62
# 19060  DEBTCONSOLIDATION          A      16000           6.92
# 37591  DEBTCONSOLIDATION          C       6000          13.99
#
#        loan_percent_income cb_person_default_on_file  \
# 2093                  0.01                         N
# ...

# %%
data = data[data["person_income"] <= 1000000]
data
# Out:
#         person_age  person_income person_home_ownership  person_emp_length  \
# 0               37          35000                  RENT                0.0
# 1               22          56000                   OWN                6.0
# 2               29          28800                   OWN                8.0
# 3               30          70000                  RENT               14.0
# 4               22          60000                  RENT                2.0
# ...            ...            ...                   ...                ...
# 100585          23          44000                  RENT                7.0
# 100586          27          42000                  RENT                3.0
# 100587          31          33530                  RENT                3.0
# 100588          31          34000                  RENT                0.0
# 100589          26          32000                  RENT                0.0
#
# ...

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=data, x="person_home_ownership", y="person_income", palette="pastel")
plt.title("Daromadlarni uy-joy mulki bo'yicha taqsimlanishi", fontsize=14)
plt.xlabel("Uy-joy mulkining turi", fontsize=12)
plt.ylabel("Daromad ", fontsize=12)

plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'{int(x):,}'))

plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()
# Out:
# C:\Users\djdle\AppData\Local\Temp\ipykernel_4852\3334695246.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x="person_home_ownership", y="person_income", palette="pastel")

# %%
# Tepadagi grafikka qarab 700 000 mingdan baland datalarni o'chirib tashlashga qaror qildik
# chunki 700 000 mingdan baland datalar juda ham ko'p emas ekan
data = data[~((data["person_income"] > 700000) & (data["person_home_ownership"] == "RENT"))]
data
# Out:
#         person_age  person_income person_home_ownership  person_emp_length  \
# 0               37          35000                  RENT                0.0
# 1               22          56000                   OWN                6.0
# 2               29          28800                   OWN                8.0
# 3               30          70000                  RENT               14.0
# 4               22          60000                  RENT                2.0
# ...            ...            ...                   ...                ...
# 100585          23          44000                  RENT                7.0
# 100586          27          42000                  RENT                3.0
# 100587          31          33530                  RENT                3.0
# 100588          31          34000                  RENT                0.0
# 100589          26          32000                  RENT                0.0
#
# ...

# %%
data = data[~((data["person_income"] > 700000) & (data["person_home_ownership"] == "OWN"))]
data
# Out:
#         person_age  person_income person_home_ownership  person_emp_length  \
# 0               37          35000                  RENT                0.0
# 1               22          56000                   OWN                6.0
# 2               29          28800                   OWN                8.0
# 3               30          70000                  RENT               14.0
# 4               22          60000                  RENT                2.0
# ...            ...            ...                   ...                ...
# 100585          23          44000                  RENT                7.0
# 100586          27          42000                  RENT                3.0
# 100587          31          33530                  RENT                3.0
# 100588          31          34000                  RENT                0.0
# 100589          26          32000                  RENT                0.0
#
# ...

# %%
data = data[~((data["person_income"] > 700000) & (data["person_home_ownership"] == "MORTGAGE"))]
data
# Out:
#         person_age  person_income person_home_ownership  person_emp_length  \
# 0               37          35000                  RENT                0.0
# 1               22          56000                   OWN                6.0
# 2               29          28800                   OWN                8.0
# 3               30          70000                  RENT               14.0
# 4               22          60000                  RENT                2.0
# ...            ...            ...                   ...                ...
# 100585          23          44000                  RENT                7.0
# 100586          27          42000                  RENT                3.0
# 100587          31          33530                  RENT                3.0
# 100588          31          34000                  RENT                0.0
# 100589          26          32000                  RENT                0.0
#
# ...

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=data, x="person_home_ownership", y="person_income", palette="pastel")
plt.title("Daromadlarni uy-joy mulki bo'yicha taqsimlanishi", fontsize=14)
plt.xlabel("Uy-joy mulkining turi", fontsize=12)
plt.ylabel("Daromad ", fontsize=12)

plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'{int(x):,}'))

plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()
# grafikga qarasak outlier datalar ko'p lekibn ularni hammasini ham o'chirib tashlash yaramaydi
# grafikda outlier datalarni qoldirmaslik uchun kamida 100 000 dan baland hamma datalarni o'chirish kerak bu yaxshi emas
# shuning uchun shunday qoldiramiz
# Out:
# C:\Users\djdle\AppData\Local\Temp\ipykernel_4852\817763978.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x="person_home_ownership", y="person_income", palette="pastel")

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x="loan_status", y="person_income", data=data)
plt.title("Shaxsning daromadi orqali kredit holati")
plt.xlabel("Kredit statusi")
plt.ylabel("Daromad")
plt.show()
# bu yerda ham outlier datalar ko'p ekan
# lekin hammasini ochirish to'g'ri emas shuning uchun
# 400 000 mingdan baland datalar unchalik ham ko'p emas ekan shularni o'chirib tashlaymiz

# %%
data = data[~((data["person_income"] > 400000) & (data["loan_status"] == 0))]
data
# Out:
#         person_age  person_income person_home_ownership  person_emp_length  \
# 0               37          35000                  RENT                0.0
# 1               22          56000                   OWN                6.0
# 2               29          28800                   OWN                8.0
# 3               30          70000                  RENT               14.0
# 4               22          60000                  RENT                2.0
# ...            ...            ...                   ...                ...
# 100585          23          44000                  RENT                7.0
# 100586          27          42000                  RENT                3.0
# 100587          31          33530                  RENT                3.0
# 100588          31          34000                  RENT                0.0
# 100589          26          32000                  RENT                0.0
#
# ...

# %%
data = data[~((data["person_income"] > 400000) & (data["loan_status"] == 1))]
data
# Out:
#         person_age  person_income person_home_ownership  person_emp_length  \
# 0               37          35000                  RENT                0.0
# 1               22          56000                   OWN                6.0
# 2               29          28800                   OWN                8.0
# 3               30          70000                  RENT               14.0
# 4               22          60000                  RENT                2.0
# ...            ...            ...                   ...                ...
# 100585          23          44000                  RENT                7.0
# 100586          27          42000                  RENT                3.0
# 100587          31          33530                  RENT                3.0
# 100588          31          34000                  RENT                0.0
# 100589          26          32000                  RENT                0.0
#
# ...

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x="loan_status", y="person_income", data=data)
plt.title("Shaxsning daromadi orqali kredit holati")
plt.xlabel("Kredit statusi")
plt.ylabel("Daromad")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x="loan_status", y="person_emp_length", data=data, palette="BuGn")
plt.title("Shaxsning ish staji orqali kredit holati")
plt.xlabel("Kredit statusi")
plt.ylabel("Ish staji")
plt.show()
# 120 yildan ortiq ish staji bor ekan bular aniq notog'ri 
# Agar minimum odam uchun ish staji hisoblanishini 14 yoshdan deb olsak(Bunday yoshdan ishlash uchun aniq bir qoidalar bor) 
# 60 yoshda pensiyaga chiqsa bu 46 yil ish staji degan
# lekin ba'zi insonlar 60 dan keyin ham ishlaydilar
# shuning uchun 60 yildan baland ish stajiga ega odamlarni o'rganib chiqamiz
# Out:
# C:\Users\djdle\AppData\Local\Temp\ipykernel_4852\3655623705.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="loan_status", y="person_emp_length", data=data, palette="BuGn")

# %%
# Kelinglar 80 yildan ortiq ish stajiga ega odamlarni yoshini ko'rib chiqamiz
data[(data["person_emp_length"] > 80)]
# bu datalar xato ekan chunki 28-yoshda bo'la turib 123 yil ish stajiga e'ga bolish mumkin emas, bularni o'chirib tashlaymiz
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 41079          28          60350              MORTGAGE              123.0
# 49252          21         192000              MORTGAGE              123.0
# 67406          28          60344                  RENT              121.0
# 78291          27          60351                  RENT              121.0
# 98454          27          60351                  RENT              123.0
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate  \
# 41079            MEDICAL          D      25000          15.95
# 49252            VENTURE          B      20000          11.49
# 67406          EDUCATION          D      25000          15.88
# 78291            MEDICAL          D      25000          15.99
# 98454  DEBTCONSOLIDATION          D      25000          15.94
#
#        loan_percent_income cb_person_default_on_file  \
# 41079                 0.35                         Y
# ...

# %%
data = data[~((data["person_emp_length"] > 80) & ((data["loan_status"] == 0) | (data["loan_status"] == 1)))]
data
# Out:
#         person_age  person_income person_home_ownership  person_emp_length  \
# 0               37          35000                  RENT                0.0
# 1               22          56000                   OWN                6.0
# 2               29          28800                   OWN                8.0
# 3               30          70000                  RENT               14.0
# 4               22          60000                  RENT                2.0
# ...            ...            ...                   ...                ...
# 100585          23          44000                  RENT                7.0
# 100586          27          42000                  RENT                3.0
# 100587          31          33530                  RENT                3.0
# 100588          31          34000                  RENT                0.0
# 100589          26          32000                  RENT                0.0
#
# ...

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x="loan_status", y="person_emp_length", data=data, palette="BuGn")
plt.title("Shaxsning ish staji orqali kredit holati")
plt.xlabel("Kredit statusi")
plt.ylabel("Ish staji")
plt.show()
# Out:
# C:\Users\djdle\AppData\Local\Temp\ipykernel_4852\2345576357.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="loan_status", y="person_emp_length", data=data, palette="BuGn")

# %%
# Endi yosh va ish stajiga qarab xato datalarni qidirib ko'ramiz
data[(data["person_emp_length"] > data["person_age"])]
# pastdagi datalarga e'tibor beradigan bo'lsak yosh ish stajidan katta ekan
# masalan 24 yoshda 51 yil stajga ega ekan
# shu datalarni o'chirib tashlaymiz
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 59930          24          60815                  RENT               51.0
# 64004          25          60848                  RENT               44.0
# 69279          26          60384                  RENT               44.0
# 71825          26          60166                  RENT               64.0
# 83751          23          60350                  RENT               38.0
# 90767          26          60379                  RENT               56.0
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate  \
# 59930            MEDICAL          D      25000          14.39
# 64004  DEBTCONSOLIDATION          D      25000          16.97
# 69279            MEDICAL          D      25000          17.30
# 71825          EDUCATION          D      25000          15.17
# 83751          EDUCATION          D      25000          15.18
# 90767            MEDICAL          D      25000          17.10
#
# ...

# %%
data.drop([59930, 64004, 69279, 71825, 83751, 90767], inplace=True)
# Out:
# C:\Users\djdle\AppData\Local\Temp\ipykernel_4852\4255108332.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop([59930, 64004, 69279, 71825, 83751, 90767], inplace=True)

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x="loan_status", y="person_emp_length", data=data, palette="BuGn")
plt.title("Shaxsning ish staji orqali kredit holati")
plt.xlabel("Kredit statusi")
plt.ylabel("Ish staji")
plt.show()
# Out:
# C:\Users\djdle\AppData\Local\Temp\ipykernel_4852\2345576357.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="loan_status", y="person_emp_length", data=data, palette="BuGn")

# %%
# ish staji 25 yildan ko'p datalar orasidan yosh va ish staji farqini ko'ramiz
data1 = data[data["person_emp_length"] > 25]
data1
# Out:
#         person_age  person_income person_home_ownership  person_emp_length  \
# 2965            42          69000              MORTGAGE               26.0
# 7117            41          32000                  RENT               26.0
# 9997            58          48000                  RENT               41.0
# 15588           80          54000                  RENT               27.0
# 17542           38         118000              MORTGAGE               27.0
# 17583           62          78000              MORTGAGE               27.0
# 17963           44          95000              MORTGAGE               28.0
# 22126           42          98000              MORTGAGE               26.0
# 24214           43          50000                  RENT               35.0
# 25260           43         120000              MORTGAGE               27.0
# 26125           43          56000                  RENT               41.0
# ...

# %%
# tepadagi datalar orasidagi farqni korib chiqamiz
data1["person_age"] - data1["person_emp_length"]
# 17542 dataga e'tibor beradigan bo'lsak 11  chiqayapti
# bu shuni bildiradiki 38 yoshlik odamda 27 yil ish staji bor ekan
# bunday natijaga eishish uchun u  11 yoshidan boshlab ishlagan bo'lishi erak, bu esa ilojsiz
# yoshlarga 14 yoshdan boshlab ayrim toifadagi ishlarga ruxsat beriladi 
# shunday datalarni o'chirib tashlaymiz
# Out:
# 2965      16.0
# 7117      15.0
# 9997      17.0
# 15588     53.0
# 17542     11.0
# 17583     35.0
# 17963     16.0
# 22126     16.0
# 24214      8.0
# 25260     16.0
# 26125      2.0
# 27072     17.0
# 27309     16.0
# 28482     15.0
# 28750     23.0
# 29271     16.0
# 29691     16.0
# 34996     34.0
# 35050     16.0
# 35544     16.0
# 36033     15.0
# 36671     16.0
# 39112     15.0
# 43900     16.0
# 45222     16.0
# 46452     18.0
# 47532     14.0
# 48287     17.0
# 48963     18.0
# 50070     16.0
# 50559     17.0
# 50694     15.0
# 52038      7.0
# 53832     15.0
# 56176      9.0
# 70020     15.0
# 81402     17.0
# 85413     16.0
# 88379     18.0
# 99087     17.0
# 100083    16.0
# dtype: float64

# %%
data.loc[17542]
# 11 yil farq
# Out:
# person_age                          38
# person_income                   118000
# person_home_ownership         MORTGAGE
# person_emp_length                 27.0
# loan_intent                    VENTURE
# loan_grade                           B
# loan_amnt                        25000
# loan_int_rate                    11.58
# loan_percent_income               0.21
# cb_person_default_on_file            N
# cb_person_cred_hist_length          13
# loan_status                          1
# Name: 17542, dtype: object

# %%
data.loc[24214]
# 8 yil farq
# Out:
# person_age                                   43
# person_income                             50000
# person_home_ownership                      RENT
# person_emp_length                          35.0
# loan_intent                   DEBTCONSOLIDATION
# loan_grade                                    A
# loan_amnt                                  9000
# loan_int_rate                              5.42
# loan_percent_income                        0.18
# cb_person_default_on_file                     N
# cb_person_cred_hist_length                   16
# loan_status                                   0
# Name: 24214, dtype: object

# %%
data.loc[26125]
# 2 yil farq
# Out:
# person_age                                 43
# person_income                           56000
# person_home_ownership                    RENT
# person_emp_length                        41.0
# loan_intent                   HOMEIMPROVEMENT
# loan_grade                                  B
# loan_amnt                                2000
# loan_int_rate                           10.99
# loan_percent_income                      0.04
# cb_person_default_on_file                   N
# cb_person_cred_hist_length                 14
# loan_status                                 0
# Name: 26125, dtype: object

# %%
data.loc[52038]
# 7 yil farq
# Out:
# person_age                          38
# person_income                    42000
# person_home_ownership         MORTGAGE
# person_emp_length                 31.0
# loan_intent                    VENTURE
# loan_grade                           B
# loan_amnt                        11000
# loan_int_rate                    11.49
# loan_percent_income               0.26
# cb_person_default_on_file            N
# cb_person_cred_hist_length          14
# loan_status                          0
# Name: 52038, dtype: object

# %%
data.loc[56176]
# 9 yil farq
# Out:
# person_age                          37
# person_income                    80000
# person_home_ownership         MORTGAGE
# person_emp_length                 28.0
# loan_intent                    VENTURE
# loan_grade                           D
# loan_amnt                        25000
# loan_int_rate                    14.46
# loan_percent_income               0.31
# cb_person_default_on_file            N
# cb_person_cred_hist_length          11
# loan_status                          0
# Name: 56176, dtype: object

# %%
# bu hamma datalarni tekshirdik endi o'chiramiz
data.drop([17542, 24214, 26125, 52038, 56176], inplace=True)
# Out:
# C:\Users\djdle\AppData\Local\Temp\ipykernel_4852\540319550.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop([17542, 24214, 26125, 52038, 56176], inplace=True)

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x="loan_status", y="person_emp_length", data=data, palette="BuGn")
plt.title("Shaxsning ish staji orqali kredit holati")
plt.xlabel("Kredit statusi")
plt.ylabel("Ish staji")
plt.show()
# Out:
# C:\Users\djdle\AppData\Local\Temp\ipykernel_4852\2345576357.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="loan_status", y="person_emp_length", data=data, palette="BuGn")

# %%
data1 = data[(data["person_emp_length"] >= 20) & (data["person_emp_length"] < 25)]
data1
# Endi 20 yil va 25 yil ish staji orasidagilarni tekshirib chiqamiz
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 86             48         112000              MORTGAGE               21.0
# 184            47          65000              MORTGAGE               21.0
# 222            51          82000              MORTGAGE               21.0
# 713            37          90000              MORTGAGE               21.0
# 868            37         114996              MORTGAGE               21.0
# ...           ...            ...                   ...                ...
# 98054          40          56099                  RENT               23.0
# 98361          22          60350                  RENT               20.0
# 98485          34         118000              MORTGAGE               20.0
# 98959          36          46000                  RENT               20.0
# 99478          37         109835                  RENT               21.0
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate  \
# ...

# %%
# 14 yildan pastlarni olamiz
for i in range(len(data1)):
    if data1.iloc[i]["person_age"] - data1.iloc[i]["person_emp_length"] < 14:
        print(data1.index[i])
        print(data1.iloc[i]["person_age"] - data1.iloc[i]["person_emp_length"])
#datalarni tekshiramiz
# Out:
# 12638
# 11.0
# 16378
# 12.0
# 17861
# 12.0
# 34852
# 12.0
# 41912
# 2.0
# 48118
# 12.0
# 65314
# 13.0
# 98361
# 2.0

# %%
data.loc[12638]
# 11 yil farq
# Out:
# person_age                          32
# person_income                    61000
# person_home_ownership         MORTGAGE
# person_emp_length                 21.0
# loan_intent                    VENTURE
# loan_grade                           B
# loan_amnt                        12000
# loan_int_rate                    11.49
# loan_percent_income                0.2
# cb_person_default_on_file            N
# cb_person_cred_hist_length           6
# loan_status                          0
# Name: 12638, dtype: object

# %%
data.loc[16378]
# 12 yil farq
# Out:
# person_age                         36
# person_income                   54400
# person_home_ownership            RENT
# person_emp_length                24.0
# loan_intent                   MEDICAL
# loan_grade                          A
# loan_amnt                        6000
# loan_int_rate                    9.63
# loan_percent_income              0.09
# cb_person_default_on_file           N
# cb_person_cred_hist_length         17
# loan_status                         1
# Name: 16378, dtype: object

# %%
data.loc[17861]
# 12 yil farq
# Out:
# person_age                          33
# person_income                    55400
# person_home_ownership         MORTGAGE
# person_emp_length                 21.0
# loan_intent                    MEDICAL
# loan_grade                           B
# loan_amnt                        18000
# loan_int_rate                    11.11
# loan_percent_income               0.33
# cb_person_default_on_file            N
# cb_person_cred_hist_length           7
# loan_status                          1
# Name: 17861, dtype: object

# %%
data.loc[34852]
# 12 yil farq
# Out:
# person_age                          36
# person_income                    87600
# person_home_ownership         MORTGAGE
# person_emp_length                 24.0
# loan_intent                    VENTURE
# loan_grade                           A
# loan_amnt                         6000
# loan_int_rate                      7.4
# loan_percent_income               0.07
# cb_person_default_on_file            N
# cb_person_cred_hist_length          11
# loan_status                          0
# Name: 34852, dtype: object

# %%
data.loc[41912]
# 2 yil farq
# Out:
# person_age                           23
# person_income                     48686
# person_home_ownership              RENT
# person_emp_length                  21.0
# loan_intent                   EDUCATION
# loan_grade                            B
# loan_amnt                         12000
# loan_int_rate                     11.86
# loan_percent_income                0.25
# cb_person_default_on_file             N
# cb_person_cred_hist_length            2
# loan_status                           0
# Name: 41912, dtype: object

# %%
data.loc[48118]
# 12 yil farq
# Out:
# person_age                          33
# person_income                    60000
# person_home_ownership         MORTGAGE
# person_emp_length                 21.0
# loan_intent                    VENTURE
# loan_grade                           B
# loan_amnt                         6000
# loan_int_rate                    10.36
# loan_percent_income                0.1
# cb_person_default_on_file            N
# cb_person_cred_hist_length           5
# loan_status                          0
# Name: 48118, dtype: object

# %%
data.loc[65314]
# 13 yil farq
# Out:
# person_age                         34
# person_income                   54256
# person_home_ownership            RENT
# person_emp_length                21.0
# loan_intent                   MEDICAL
# loan_grade                          D
# loan_amnt                        6000
# loan_int_rate                    9.22
# loan_percent_income               0.1
# cb_person_default_on_file           Y
# cb_person_cred_hist_length         12
# loan_status                         1
# Name: 65314, dtype: object

# %%
data.loc[98361]
# 2 yil farq
# Out:
# person_age                           22
# person_income                     60350
# person_home_ownership              RENT
# person_emp_length                  20.0
# loan_intent                   EDUCATION
# loan_grade                            D
# loan_amnt                         25000
# loan_int_rate                     15.01
# loan_percent_income                0.35
# cb_person_default_on_file             N
# cb_person_cred_hist_length            4
# loan_status                           1
# Name: 98361, dtype: object

# %%
#bu datalarni ham o'chiramiz
data.drop([12638, 16378, 17861, 34852, 41912, 48118, 65314, 98361], inplace=True)
# Out:
# C:\Users\djdle\AppData\Local\Temp\ipykernel_4852\266163388.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop([12638, 16378, 17861, 34852, 41912, 48118, 65314, 98361], inplace=True)

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x="loan_status", y="person_emp_length", data=data, palette="BuGn")
plt.title("Shaxsning ish staji orqali kredit holati")
plt.xlabel("Kredit statusi")
plt.ylabel("Ish staji")
plt.show()
# Out:
# C:\Users\djdle\AppData\Local\Temp\ipykernel_4852\2345576357.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="loan_status", y="person_emp_length", data=data, palette="BuGn")

# %%
data1 = data[(data["person_emp_length"] >= 15) & (data["person_emp_length"] < 20)]
data1
# Endi 15 yil va 20 yil ish staji orasidagilarni tekshirib chiqamiz
# Out:
#         person_age  person_income person_home_ownership  person_emp_length  \
# 104             33          46000              MORTGAGE               17.0
# 132             32         150000                  RENT               16.0
# 145             34          54000              MORTGAGE               16.0
# 261             32          55000              MORTGAGE               16.0
# 278             34          85000              MORTGAGE               18.0
# ...            ...            ...                   ...                ...
# 99377           33          56000                  RENT               18.0
# 99675           33          34000                  RENT               15.0
# 99753           31          55386                  RENT               18.0
# 100162          31          56442                  RENT               15.0
# 100330          32          62400                  RENT               17.0
#
#               loan_intent loan_grade  loan_amnt  loan_int_rate  \
# ...

# %%
for i in range(len(data1)):
    if data1.iloc[i]["person_age"] - data1.iloc[i]["person_emp_length"] < 14:
        print(data1.index[i])
        print(data1.iloc[i]["person_age"] - data1.iloc[i]["person_emp_length"])
#datalarni tekshiramiz
# Out:
# 699
# 11.0
# 746
# 6.0
# 32236
# 8.0
# 43518
# 6.0
# 61605
# 5.0
# 69328
# 12.0
# 73199
# 13.0
# 99753
# 13.0

# %%
data.loc[699]
# 11 yil farq
# Out:
# person_age                          30
# person_income                    76500
# person_home_ownership         MORTGAGE
# person_emp_length                 19.0
# loan_intent                    MEDICAL
# loan_grade                           A
# loan_amnt                        14750
# loan_int_rate                     6.62
# loan_percent_income                0.2
# cb_person_default_on_file            N
# cb_person_cred_hist_length           8
# loan_status                          0
# Name: 699, dtype: object

# %%
data.loc[746]
# 6 yil farq
# Out:
# person_age                          23
# person_income                   100000
# person_home_ownership         MORTGAGE
# person_emp_length                 17.0
# loan_intent                   PERSONAL
# loan_grade                           A
# loan_amnt                        17000
# loan_int_rate                     7.49
# loan_percent_income               0.17
# cb_person_default_on_file            N
# cb_person_cred_hist_length           3
# loan_status                          0
# Name: 746, dtype: object

# %%
data.loc[32236]
# 8 yil farq
# Out:
# person_age                           23
# person_income                     25596
# person_home_ownership              RENT
# person_emp_length                  15.0
# loan_intent                   EDUCATION
# loan_grade                            A
# loan_amnt                          5000
# loan_int_rate                       7.9
# loan_percent_income                 0.2
# cb_person_default_on_file             N
# cb_person_cred_hist_length            4
# loan_status                           0
# Name: 32236, dtype: object

# %%
data.loc[43518]
# 6 yil farq
# Out:
# person_age                         25
# person_income                   42000
# person_home_ownership            RENT
# person_emp_length                19.0
# loan_intent                   MEDICAL
# loan_grade                          C
# loan_amnt                        6000
# loan_int_rate                   13.49
# loan_percent_income              0.14
# cb_person_default_on_file           N
# cb_person_cred_hist_length          4
# loan_status                         0
# Name: 43518, dtype: object

# %%
data.loc[61605]
# 5 yil farq
# Out:
# person_age                                   24
# person_income                             61002
# person_home_ownership                      RENT
# person_emp_length                          19.0
# loan_intent                   DEBTCONSOLIDATION
# loan_grade                                    D
# loan_amnt                                 25000
# loan_int_rate                             17.29
# loan_percent_income                         0.4
# cb_person_default_on_file                     N
# cb_person_cred_hist_length                    4
# loan_status                                   1
# Name: 61605, dtype: object

# %%
data.loc[69328]
# 12 yil farq
# Out:
# person_age                                   28
# person_income                             85911
# person_home_ownership                      RENT
# person_emp_length                          16.0
# loan_intent                   DEBTCONSOLIDATION
# loan_grade                                    B
# loan_amnt                                 23825
# loan_int_rate                             10.25
# loan_percent_income                        0.27
# cb_person_default_on_file                     N
# cb_person_cred_hist_length                    6
# loan_status                                   1
# Name: 69328, dtype: object

# %%
data.loc[73199]
# 13 yil farq
# Out:
# person_age                           29
# person_income                     55377
# person_home_ownership              RENT
# person_emp_length                  16.0
# loan_intent                   EDUCATION
# loan_grade                            B
# loan_amnt                         18000
# loan_int_rate                     12.36
# loan_percent_income                0.33
# cb_person_default_on_file             N
# cb_person_cred_hist_length            4
# loan_status                           1
# Name: 73199, dtype: object

# %%
data.loc[99753]
# 13 yil farq ekan
# Out:
# person_age                           31
# person_income                     55386
# person_home_ownership              RENT
# person_emp_length                  18.0
# loan_intent                   EDUCATION
# loan_grade                            B
# loan_amnt                         18000
# loan_int_rate                     11.84
# loan_percent_income                0.33
# cb_person_default_on_file             N
# cb_person_cred_hist_length            5
# loan_status                           1
# Name: 99753, dtype: object

# %%
#bu datalarni ham o'chiramiz
data.drop([699, 746, 32236, 43518, 61605, 69328, 73199, 99753], inplace=True)
# Out:
# C:\Users\djdle\AppData\Local\Temp\ipykernel_4852\3924900795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop([699, 746, 32236, 43518, 61605, 69328, 73199, 99753], inplace=True)

# %%
data1 = data[(data["person_emp_length"] >= 10) & (data["person_emp_length"] < 15)]
data1
# endi 10 va 15 yil orasidagilarni ko'rib chiqamiz
# Out:
#         person_age  person_income person_home_ownership  person_emp_length  \
# 3               30          70000                  RENT               14.0
# 8               37          69600                  RENT               11.0
# 17              29          60000                   OWN               13.0
# 22              26          95000              MORTGAGE               10.0
# 26              28          75000              MORTGAGE               12.0
# ...            ...            ...                   ...                ...
# 100511          30         102801                  RENT               11.0
# 100547          33          62400              MORTGAGE               14.0
# 100552          27          58935                  RENT               10.0
# 100573          26          64000              MORTGAGE               10.0
# 100578          25          77956              MORTGAGE               10.0
#
#               loan_intent loan_grade  loan_amnt  loan_int_rate  \
# ...

# %%
for i in range(len(data1)):
    if data1.iloc[i]["person_age"] - data1.iloc[i]["person_emp_length"] < 14:
        print(data1.index[i])
        print(data1.iloc[i]["person_age"] - data1.iloc[i]["person_emp_length"])
#datalarni tekshiramiz
# Out:
# 3072
# 12.0
# 8222
# 13.0
# 15921
# 13.0
# 18293
# 13.0
# 18783
# 9.0
# 33012
# 10.0
# 48185
# 13.0
# 48915
# 12.0
# 53992
# 12.0
# 58602
# 9.0
# 71875
# 11.0
# 81175
# 11.0
# 81367
# 10.0
# 83549
# 12.0
# 90798
# 13.0

# %%
data.loc[3072]
# 12 yil farq
# Out:
# person_age                                 24
# person_income                           72000
# person_home_ownership                    RENT
# person_emp_length                        12.0
# loan_intent                   HOMEIMPROVEMENT
# loan_grade                                  B
# loan_amnt                               14000
# loan_int_rate                           12.69
# loan_percent_income                      0.19
# cb_person_default_on_file                   N
# cb_person_cred_hist_length                  2
# loan_status                                 0
# Name: 3072, dtype: object

# %%
data.loc[8222]
# 13 yil farq
# Out:
# person_age                           26
# person_income                     64999
# person_home_ownership          MORTGAGE
# person_emp_length                  13.0
# loan_intent                   EDUCATION
# loan_grade                            B
# loan_amnt                         12000
# loan_int_rate                     10.99
# loan_percent_income                0.17
# cb_person_default_on_file             N
# cb_person_cred_hist_length            3
# loan_status                           0
# Name: 8222, dtype: object

# %%
data.loc[15921]
# 13 yil farq
# Out:
# person_age                         27
# person_income                   70000
# person_home_ownership            RENT
# person_emp_length                14.0
# loan_intent                   VENTURE
# loan_grade                          E
# loan_amnt                        9000
# loan_int_rate                    16.0
# loan_percent_income              0.13
# cb_person_default_on_file           Y
# cb_person_cred_hist_length          7
# loan_status                         0
# Name: 15921, dtype: object

# %%
data.loc[18293]
# 13 yil farq
# Out:
# person_age                          23
# person_income                    36194
# person_home_ownership             RENT
# person_emp_length                 10.0
# loan_intent                   PERSONAL
# loan_grade                           B
# loan_amnt                         9250
# loan_int_rate                    10.08
# loan_percent_income               0.26
# cb_person_default_on_file            N
# cb_person_cred_hist_length           3
# loan_status                          0
# Name: 18293, dtype: object

# %%
data.loc[18783]
# 9 yil farq
# Out:
# person_age                         22
# person_income                   29000
# person_home_ownership            RENT
# person_emp_length                13.0
# loan_intent                   VENTURE
# loan_grade                          A
# loan_amnt                       10000
# loan_int_rate                    8.49
# loan_percent_income              0.34
# cb_person_default_on_file           N
# cb_person_cred_hist_length          3
# loan_status                         1
# Name: 18783, dtype: object

# %%
data.loc[33012]
# 10 yil farq
# Out:
# person_age                         24
# person_income                   33000
# person_home_ownership             OWN
# person_emp_length                14.0
# loan_intent                   MEDICAL
# loan_grade                          A
# loan_amnt                        1000
# loan_int_rate                    5.42
# loan_percent_income              0.03
# cb_person_default_on_file           N
# cb_person_cred_hist_length          3
# loan_status                         0
# Name: 33012, dtype: object

# %%
data.loc[48185]
# 13 yil farq
# Out:
# person_age                                   23
# person_income                             76066
# person_home_ownership                      RENT
# person_emp_length                          10.0
# loan_intent                   DEBTCONSOLIDATION
# loan_grade                                    D
# loan_amnt                                 24250
# loan_int_rate                             15.65
# loan_percent_income                        0.32
# cb_person_default_on_file                     Y
# cb_person_cred_hist_length                    3
# loan_status                                   1
# Name: 48185, dtype: object

# %%
data.loc[48915]
# 12 yil farq
# Out:
# person_age                                   22
# person_income                             32000
# person_home_ownership                      RENT
# person_emp_length                          10.0
# loan_intent                   DEBTCONSOLIDATION
# loan_grade                                    A
# loan_amnt                                  4200
# loan_int_rate                              6.39
# loan_percent_income                        0.13
# cb_person_default_on_file                     N
# cb_person_cred_hist_length                    3
# loan_status                                   0
# Name: 48915, dtype: object

# %%
data.loc[53992]
# 12 yil farq
# Out:
# person_age                          23
# person_income                    91000
# person_home_ownership              OWN
# person_emp_length                 11.0
# loan_intent                   PERSONAL
# loan_grade                           A
# loan_amnt                        15000
# loan_int_rate                     6.17
# loan_percent_income               0.16
# cb_person_default_on_file            N
# cb_person_cred_hist_length           2
# loan_status                          0
# Name: 53992, dtype: object

# %%
data.loc[58602]
# 9 yil farq
# Out:
# person_age                                   23
# person_income                             86000
# person_home_ownership                  MORTGAGE
# person_emp_length                          14.0
# loan_intent                   DEBTCONSOLIDATION
# loan_grade                                    B
# loan_amnt                                 25000
# loan_int_rate                             11.12
# loan_percent_income                        0.29
# cb_person_default_on_file                     N
# cb_person_cred_hist_length                    2
# loan_status                                   1
# Name: 58602, dtype: object

# %%
data.loc[71875]
# 11 yil farq
# Out:
# person_age                         22
# person_income                   29001
# person_home_ownership            RENT
# person_emp_length                11.0
# loan_intent                   MEDICAL
# loan_grade                          B
# loan_amnt                       10000
# loan_int_rate                     8.2
# loan_percent_income              0.34
# cb_person_default_on_file           N
# cb_person_cred_hist_length          2
# loan_status                         1
# Name: 71875, dtype: object

# %%
data.loc[81175]
# 11 yil farq
# Out:
# person_age                         22
# person_income                   60350
# person_home_ownership            RENT
# person_emp_length                11.0
# loan_intent                   MEDICAL
# loan_grade                          D
# loan_amnt                       25000
# loan_int_rate                   14.94
# loan_percent_income              0.35
# cb_person_default_on_file           Y
# cb_person_cred_hist_length          4
# loan_status                         1
# Name: 81175, dtype: object

# %%
data.loc[81367]
# 10 yil farq
# Out:
# person_age                         22
# person_income                   29000
# person_home_ownership            RENT
# person_emp_length                12.0
# loan_intent                   MEDICAL
# loan_grade                          B
# loan_amnt                       10000
# loan_int_rate                     8.7
# loan_percent_income              0.34
# cb_person_default_on_file           N
# cb_person_cred_hist_length          2
# loan_status                         1
# Name: 81367, dtype: object

# %%
data.loc[83549]
# 12 yil farq
# Out:
# person_age                                   25
# person_income                             86000
# person_home_ownership                      RENT
# person_emp_length                          13.0
# loan_intent                   DEBTCONSOLIDATION
# loan_grade                                    D
# loan_amnt                                 25000
# loan_int_rate                              11.6
# loan_percent_income                        0.29
# cb_person_default_on_file                     N
# cb_person_cred_hist_length                    3
# loan_status                                   1
# Name: 83549, dtype: object

# %%
data.loc[90798]
# 13 yil farq
# Out:
# person_age                                   25
# person_income                             85661
# person_home_ownership                      RENT
# person_emp_length                          12.0
# loan_intent                   DEBTCONSOLIDATION
# loan_grade                                    D
# loan_amnt                                 25000
# loan_int_rate                             12.56
# loan_percent_income                        0.29
# cb_person_default_on_file                     Y
# cb_person_cred_hist_length                    3
# loan_status                                   1
# Name: 90798, dtype: object

# %%
#bu datalarni ham o'chiramiz
data.drop([3072, 8222, 15921, 18293, 18783, 33012, 48185, 48915, 53992, 58602, 71875, 81175, 81367, 83549, 90798], inplace=True)
# Out:
# C:\Users\djdle\AppData\Local\Temp\ipykernel_4852\1091940678.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop([3072, 8222, 15921, 18293, 18783, 33012, 48185, 48915, 53992, 58602, 71875, 81175, 81367, 83549, 90798], inplace=True)

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x="loan_status", y="person_emp_length", data=data, palette="BuGn")
plt.title("Shaxsning ish staji orqali kredit holati")
plt.xlabel("Kredit statusi")
plt.ylabel("Ish staji")
plt.show()
# Out:
# C:\Users\djdle\AppData\Local\Temp\ipykernel_4852\2345576357.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="loan_status", y="person_emp_length", data=data, palette="BuGn")

# %%
data1 = data[(data["person_emp_length"] >= 5) & (data["person_emp_length"] < 10)]
data1
# endi 5 va 10 yil orasidagilarni ko'rib chiqamiz
# Out:
#         person_age  person_income person_home_ownership  person_emp_length  \
# 1               22          56000                   OWN                6.0
# 2               29          28800                   OWN                8.0
# 6               25          45000              MORTGAGE                9.0
# 10              30          78000              MORTGAGE                5.0
# 11              22          33000                  RENT                6.0
# ...            ...            ...                   ...                ...
# 100575          22          42000                  RENT                6.0
# 100576          33          48996                  RENT                5.0
# 100582          30          78000                  RENT                5.0
# 100583          33          38000                  RENT                5.0
# 100585          23          44000                  RENT                7.0
#
#               loan_intent loan_grade  loan_amnt  loan_int_rate  \
# ...

# %%
for i in range(len(data1)):
    if data1.iloc[i]["person_age"] - data1.iloc[i]["person_emp_length"] < 14:
        print(data1.index[i])
        print(data1.iloc[i]["person_age"] - data1.iloc[i]["person_emp_length"])
# Out:
# 20615
# 13.0
# 87064
# 13.0

# %%
data.loc[20615]
# 13 yil farq
# Out:
# person_age                          21
# person_income                    50000
# person_home_ownership             RENT
# person_emp_length                  8.0
# loan_intent                   PERSONAL
# loan_grade                           D
# loan_amnt                        15000
# loan_int_rate                    17.58
# loan_percent_income                0.3
# cb_person_default_on_file            Y
# cb_person_cred_hist_length           3
# loan_status                          0
# Name: 20615, dtype: object

# %%
data.loc[87064]
# 13 yil farq
# Out:
# person_age                         22
# person_income                   29002
# person_home_ownership            RENT
# person_emp_length                 9.0
# loan_intent                   MEDICAL
# loan_grade                          B
# loan_amnt                       10000
# loan_int_rate                    7.93
# loan_percent_income              0.34
# cb_person_default_on_file           N
# cb_person_cred_hist_length          2
# loan_status                         1
# Name: 87064, dtype: object

# %%
# bu datalarni ham o'chiramiz
data.drop([20615, 87064], inplace=True)
# Out:
# C:\Users\djdle\AppData\Local\Temp\ipykernel_4852\3372546864.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop([20615, 87064], inplace=True)

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x="loan_status", y="person_emp_length", data=data, palette="BuGn")
plt.title("Shaxsning ish staji orqali kredit holati")
plt.xlabel("Kredit statusi")
plt.ylabel("Ish staji")
plt.show()
# Out:
# C:\Users\djdle\AppData\Local\Temp\ipykernel_4852\2345576357.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="loan_status", y="person_emp_length", data=data, palette="BuGn")

# %%
# keling endi kredit summasi va kredit holatini ko'rib chiqamiz
plt.figure(figsize=(10, 6))
sns.boxplot(x="loan_status", y="loan_amnt", data=data, palette="RdYlBu")
plt.title("Shaxsning kredit summasi boyicha kredit holati")
plt.xlabel("Kredit statusi")
plt.ylabel("Kredit summasi")
plt.show()
# ko'rishimiz mumkunki, eng katta kredit miqdori 35 000 ekan
# outlier datalar taxminan 23 000 mingdan baland ekan, hozircha ularni o'chirmaymiz
# Out:
# C:\Users\djdle\AppData\Local\Temp\ipykernel_4852\3152825766.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="loan_status", y="loan_amnt", data=data, palette="RdYlBu")

# %%
# Endi kredit maqsadi va kredit summasi grafigini ko'ramiz
# styleni o'rnatib olamiz
sns.set_theme(style="darkgrid")

plt.figure(figsize=(10, 6))

# boxplot
boxplot = sns.boxplot(data=data, x="loan_intent", y="loan_amnt", palette="muted", linewidth=2.5)

# kredit statusini sonini hisoblaymiz
counts_total = data["loan_intent"].value_counts()
counts_status_0 = data[data["loan_status"] == 0]["loan_intent"].value_counts()
counts_status_1 = data[data["loan_status"] == 1]["loan_intent"].value_counts()

# kredit statusi sonini boxplotning tagiga yozamiz
for i, category in enumerate(counts_total.index):
    total = counts_total[category]
    status_0 = counts_status_0.get(category, 0)
    status_1 = counts_status_1.get(category, 0)
    
    #  har bir grafik tagiga yozamiz
    plt.text(i, -0.1, f'Umumiy={total}\n(R={status_0}, T={status_1})', # R-Rad etilgan, T-Tasdiqlangan
             ha='center', va='top', fontsize=10, color='black')

plt.title("Kredit summasining kredit turiga qarab taqsimlanishi", fontsize=16, fontweight='bold')
plt.xlabel("Kreditning maqsadi", fontsize=12)
plt.ylabel("Kredit summasi", fontsize=12)
plt.xticks(fontsize=10, rotation=45) 
plt.yticks(fontsize=10)
sns.despine(left=True, bottom=True)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\djdle\AppData\Local\Temp\ipykernel_4852\4228371752.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   boxplot = sns.boxplot(data=data, x="loan_intent", y="loan_amnt", palette="muted", linewidth=2.5)

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x="loan_status", y="loan_int_rate", data=data, palette={"0": "red", "1": "lime"})
plt.title("Kredit bo'yicha foiz miqdorining kredit olishga ta'siri")
plt.xlabel("Kredit statusi")
plt.ylabel("Kredit foizi")
plt.show()
# ko'rishimiz mumkinki kredit foizi ko'p bo'lganda kredit olish yaxshiroq ekan
# bu banklar foyda ko'rishi uchun foydaliroq bo'lgani uchun ham bo'lishi mumkin
# Out:
# C:\Users\djdle\AppData\Local\Temp\ipykernel_4852\7697702.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="loan_status", y="loan_int_rate", data=data, palette={"0": "red", "1": "lime"})

# %%
plt.figure(figsize=(10, 10))
sns.boxplot(x="loan_status", y="loan_percent_income", data=data, palette={"0": "darkred", "1": "darkgreen"})
plt.title("Kredit oluvchining yillik daromadining necha foizini kreditni to'lash uchun sarflashni rejalashtirayotganini kredit olishga ta'siri")
plt.xlabel("Kredit statusi")
plt.ylabel("Kredit oluvchining yillik daromadining necha foizini kreditni to'lash uchun sarflashni rejalashtirayotganini ko'rsatadi")
plt.show()
# bu kredit oluvchining yillik daromadining necha foizini kreditni to'lash uchun sarflashni rejalashtirayotganini ko'rsatadi
# ko'rishingiz mumkinki daromadimizni qanchalik ko'proq qismini sarflashimizga qarab kredit olish ham shunchalik baland bo'lishi mumkin
# Out:
# C:\Users\djdle\AppData\Local\Temp\ipykernel_4852\1418976743.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="loan_status", y="loan_percent_income", data=data, palette={"0": "darkred", "1": "darkgreen"})

# %%
# biz tepada korrelatsiyasi faqat sonli ustunlarga nisbatan ko'rgan edik endi hamma ustunlarga nisbatan ko'ramiz
data_numeric = data.copy()

# %%
for col in categorical_columns:
    data_numeric[col] = le.fit_transform(data_numeric[col])

# %%
plt.subplots(figsize=(9,9))
sns.heatmap(data_numeric.corr(),annot=True, fmt='.2f', cmap='coolwarm')
# Out:
# <Axes: >

# %%
data_numeric.corrwith(data_numeric["loan_status"]).sort_values()
# demak loan_statusga object ustulardan, loan_grade ni korelatsiyasi baland ekan keling shu bo'yicha ko'ramiz
# Out:
# person_income                -0.307183
# person_emp_length            -0.167867
# loan_intent                  -0.093372
# cb_person_cred_hist_length   -0.069859
# person_age                   -0.056841
# cb_person_default_on_file     0.145224
# loan_amnt                     0.188929
# person_home_ownership         0.410753
# loan_percent_income           0.440864
# loan_int_rate                 0.473600
# loan_grade                    0.502631
# loan_status                   1.000000
# dtype: float64

# %%
loan_grade_status_counts = data.groupby(["loan_grade", "loan_status"]).size().unstack()

loan_grade_status_counts.plot(kind="bar", figsize=(10, 6))
plt.title("Kredit bo'yicha reytingni, kredit statusi bo'yicha taqsimlanishi", fontsize=16)
plt.xlabel("Kredit reytingi", fontsize=12)
plt.ylabel("Soni", fontsize=12)
plt.xticks(rotation=45, fontsize=10)
plt.legend(title="Kredit statusi", fontsize=10)
plt.tight_layout()

plt.show()
# E'tibor beradigan bo'lsak D reytingda ko'proq kredit berilgan ekan

# %%
# Keling endi shu kredit reyting bo'yicha defaul bor yo'qligini ko'ramiz
loan_grade_default_counts = data.groupby(["loan_grade", "cb_person_default_on_file"]).size().unstack()

loan_grade_default_counts.plot(kind="bar", figsize=(12, 6), color=["#1f77b4", "#ff7f0e"], edgecolor="black")

plt.title("Kredit reytingi bo'yicha defaultni ko'rish", fontsize=16, fontweight='bold')
plt.xlabel("Kredit reytingi", fontsize=12)
plt.ylabel("Soni", fontsize=12)
plt.xticks(rotation=0, fontsize=10)
plt.yticks(fontsize=10)
plt.legend(["Default yo'q (N)", "Default bor (Y)"], title="Default", fontsize=10)
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()
# ko'radingan bo'lsak tepadagi grafikda eng ko'p D reytingdagi odamlar kredit olishga muvofiq bo'lgan
# pastdagi grafikga ko'rsak eng ko'p default ham D reytingda ekan

# %%
# Uy-joy turi va kredit holati bo'yicha daromadlarni taqsimlashni ko'rib chiqamiz
plt.figure(figsize=(10, 6))
sns.boxplot(x="person_home_ownership", y="person_income", hue="loan_status", data=data, palette="Set2")
plt.title("Uy-joy turi va kredit holati bo'yicha daromadlarni taqsimlash")
plt.xlabel("Uy-joy turi")
plt.ylabel("Daromad")
plt.legend(title="Kredit statusi")
plt.xticks(rotation=45)
plt.show()
# outlier datalar ko'p ekan lekin 350 000 mingdan baland outlier datalar ko'p emas shuning uchun ularni o'chiramiz

# %%
data = data[~((data["person_home_ownership"] == "RENT") & (data["person_income"] > 350000) & (data["loan_status"] == 0))]
data
# Out:
#         person_age  person_income person_home_ownership  person_emp_length  \
# 0               37          35000                  RENT                0.0
# 1               22          56000                   OWN                6.0
# 2               29          28800                   OWN                8.0
# 3               30          70000                  RENT               14.0
# 4               22          60000                  RENT                2.0
# ...            ...            ...                   ...                ...
# 100585          23          44000                  RENT                7.0
# 100586          27          42000                  RENT                3.0
# 100587          31          33530                  RENT                3.0
# 100588          31          34000                  RENT                0.0
# 100589          26          32000                  RENT                0.0
#
# ...

# %%
data = data[~((data["person_home_ownership"] == "RENT") & (data["person_income"] > 350000) & (data["loan_status"] == 1))]
data
# Out:
#         person_age  person_income person_home_ownership  person_emp_length  \
# 0               37          35000                  RENT                0.0
# 1               22          56000                   OWN                6.0
# 2               29          28800                   OWN                8.0
# 3               30          70000                  RENT               14.0
# 4               22          60000                  RENT                2.0
# ...            ...            ...                   ...                ...
# 100585          23          44000                  RENT                7.0
# 100586          27          42000                  RENT                3.0
# 100587          31          33530                  RENT                3.0
# 100588          31          34000                  RENT                0.0
# 100589          26          32000                  RENT                0.0
#
# ...

# %%
data = data[~((data["person_home_ownership"] == "OWN") & (data["person_income"] > 350000) & (data["loan_status"] == 0))]
data
# Out:
#         person_age  person_income person_home_ownership  person_emp_length  \
# 0               37          35000                  RENT                0.0
# 1               22          56000                   OWN                6.0
# 2               29          28800                   OWN                8.0
# 3               30          70000                  RENT               14.0
# 4               22          60000                  RENT                2.0
# ...            ...            ...                   ...                ...
# 100585          23          44000                  RENT                7.0
# 100586          27          42000                  RENT                3.0
# 100587          31          33530                  RENT                3.0
# 100588          31          34000                  RENT                0.0
# 100589          26          32000                  RENT                0.0
#
# ...

# %%
data = data[~((data["person_home_ownership"] == "OWN") & (data["person_income"] > 350000) & (data["loan_status"] == 1))]
data
# Out:
#         person_age  person_income person_home_ownership  person_emp_length  \
# 0               37          35000                  RENT                0.0
# 1               22          56000                   OWN                6.0
# 2               29          28800                   OWN                8.0
# 3               30          70000                  RENT               14.0
# 4               22          60000                  RENT                2.0
# ...            ...            ...                   ...                ...
# 100585          23          44000                  RENT                7.0
# 100586          27          42000                  RENT                3.0
# 100587          31          33530                  RENT                3.0
# 100588          31          34000                  RENT                0.0
# 100589          26          32000                  RENT                0.0
#
# ...

# %%
data = data[~((data["person_home_ownership"] == "MORTGAGE") & (data["person_income"] > 350000) & (data["loan_status"] == 0))]
data
# Out:
#         person_age  person_income person_home_ownership  person_emp_length  \
# 0               37          35000                  RENT                0.0
# 1               22          56000                   OWN                6.0
# 2               29          28800                   OWN                8.0
# 3               30          70000                  RENT               14.0
# 4               22          60000                  RENT                2.0
# ...            ...            ...                   ...                ...
# 100585          23          44000                  RENT                7.0
# 100586          27          42000                  RENT                3.0
# 100587          31          33530                  RENT                3.0
# 100588          31          34000                  RENT                0.0
# 100589          26          32000                  RENT                0.0
#
# ...

# %%
data = data[~((data["person_home_ownership"] == "MORTGAGE") & (data["person_income"] > 350000) & (data["loan_status"] == 1))]
data
# Out:
#         person_age  person_income person_home_ownership  person_emp_length  \
# 0               37          35000                  RENT                0.0
# 1               22          56000                   OWN                6.0
# 2               29          28800                   OWN                8.0
# 3               30          70000                  RENT               14.0
# 4               22          60000                  RENT                2.0
# ...            ...            ...                   ...                ...
# 100585          23          44000                  RENT                7.0
# 100586          27          42000                  RENT                3.0
# 100587          31          33530                  RENT                3.0
# 100588          31          34000                  RENT                0.0
# 100589          26          32000                  RENT                0.0
#
# ...

# %%
data = data[~((data["person_home_ownership"] == "OTHER") & (data["person_income"] > 350000) & (data["loan_status"] == 0))]
data
# Out:
#         person_age  person_income person_home_ownership  person_emp_length  \
# 0               37          35000                  RENT                0.0
# 1               22          56000                   OWN                6.0
# 2               29          28800                   OWN                8.0
# 3               30          70000                  RENT               14.0
# 4               22          60000                  RENT                2.0
# ...            ...            ...                   ...                ...
# 100585          23          44000                  RENT                7.0
# 100586          27          42000                  RENT                3.0
# 100587          31          33530                  RENT                3.0
# 100588          31          34000                  RENT                0.0
# 100589          26          32000                  RENT                0.0
#
# ...

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x="person_home_ownership", y="person_income", hue="loan_status", data=data, palette="Set2")
plt.title("Uy-joy turi va kredit holati bo'yicha daromadlarni taqsimlash")
plt.xlabel("Uy-joy turi")
plt.ylabel("Daromad")
plt.legend(title="Kredit statusi")
plt.xticks(rotation=45)  
plt.show()

# %%
# Keling endi yosh bo'yicha ham ko'rib chiqsak
plt.figure(figsize=(10, 6))
sns.boxplot(x="loan_intent", y="person_age", hue="loan_status", data=data, palette="Set2")
plt.title("Kredit oluvchilarning yoshi va kredit maqsadlari")
plt.xlabel("Kreditning maqsadi")
plt.ylabel("Yosh")
plt.legend(title="Kredit statusi")
plt.xticks(rotation=45)  
plt.show()
# e'tibor beradigan bo'lsak 120 yoshdan katta odam bor ekan shu tekshirib ko'ramiz

# %%
data[data["person_age"]>120]
# bu data 1 dana ekan va boshqa datalarda juda ham uzoqda ekan shuning uchun o'chirib tashlaymiz
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 47336         123          36000              MORTGAGE                7.0
#
#       loan_intent loan_grade  loan_amnt  loan_int_rate  loan_percent_income  \
# 47336    PERSONAL          B       6700          10.75                 0.18
#
#       cb_person_default_on_file  cb_person_cred_hist_length  loan_status
# 47336                         N                           4            0

# %%
data = data[data["person_age"] <= 120]
data
# Out:
#         person_age  person_income person_home_ownership  person_emp_length  \
# 0               37          35000                  RENT                0.0
# 1               22          56000                   OWN                6.0
# 2               29          28800                   OWN                8.0
# 3               30          70000                  RENT               14.0
# 4               22          60000                  RENT                2.0
# ...            ...            ...                   ...                ...
# 100585          23          44000                  RENT                7.0
# 100586          27          42000                  RENT                3.0
# 100587          31          33530                  RENT                3.0
# 100588          31          34000                  RENT                0.0
# 100589          26          32000                  RENT                0.0
#
# ...

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x="loan_intent", y="person_age", hue="loan_status", data=data, palette="Set2")
plt.title("Kredit oluvchilarning yoshi va kredit maqsadlari")
plt.xlabel("Kreditning maqsadi")
plt.ylabel("Yosh")
plt.legend(title="Kredit statusi")
plt.xticks(rotation=45)  
plt.show()
# qolgan datalarni olib qolamiz

# %% [markdown]
# <div style="border-radius:50px; padding: 1px; background-color: #26bfbf; font-size:130%; text-align:left">
# <h3 align="left"><font color="navy"> <center><center> 5-qadam. XGBOOST. </font></h3>
# </div>

# %% [markdown]
# <center>
#
# # ![44772a20-0f93-4f49-8a1a-f7d2f68c943f_485x649.jpg](attachment:351cfa0f-67ec-4a54-bfef-67ea6ad1c9e8.jpg)

# %%
data_numeric = data.copy()

# %%
# object ustunlarni belgilab olamiz
categorical_columns = data_numeric.select_dtypes(include=['object']).columns
categorical_columns
# Out:
# Index(['person_home_ownership', 'loan_intent', 'loan_grade',
#        'cb_person_default_on_file'],
#       dtype='object')

# %%
# Label encoder orqali object ustunlarni encode qilib olamiz
label_encoders = {}
for col in categorical_columns:
    label_encoders[col] = LabelEncoder()
    data_numeric[col] = label_encoders[col].fit_transform(data_numeric[col].astype(str))

# %%
# Kerakli kutubxonalar
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score

# %%
# train va test datalarni o'qib olamiz
train_data = data_numeric.copy()
test_data = pd.read_csv("Datasets/kredit/test.csv")

# %%
test_data.drop(["id"], axis=1, inplace=True)

# %%
# test data-ni ham encode qilib olamiz
for col in categorical_columns:
    test_data[col] = label_encoders[col].transform(test_data[col].astype(str))

# %%
X_train = train_data.drop("loan_status", axis=1)
y_train = train_data["loan_status"]

# %%
import xgboost as xgb

# modelni yaratamiz
xgb_model = xgb.XGBClassifier(n_estimators=100, 
                              learning_rate=0.1, 
                              max_depth=6,
                              random_state=42)

# modelni o'qitamiz
xgb_model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)

# %%
from sklearn.metrics import accuracy_score

# bashorat(predict)
y_pred_train = xgb_model.predict(X_train)

# Aniqlik darajasi
train_accuracy = accuracy_score(y_train, y_pred_train)
print(f"Train datadagi aniqlik darajasi : {train_accuracy * 100:.2f}%")
# Out:
# Train datadagi aniqlik darajasi : 94.64%

# %% [markdown]
# # <center> <h1> 👨‍💻   🚀
